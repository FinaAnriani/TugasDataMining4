# %% [markdown]
# <a href="https://colab.research.google.com/github/FinaAnriani/TugasDataMining4/blob/main/Tugasdatmin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Nama : Fina Anriani**
# #**NIM : 2209116051**
# #**Kelas : Sistem Informasi A 2022**
# #**Sesi : A2**

# %% [markdown]
# #**Faktor-faktor yang Mempengaruhi seseorang Berbelanja di Online Store**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib.patches import Patch
from matplotlib.ticker import PercentFormatter
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# #**Business Objective**

# %% [markdown]
# Tujuan bisnis dari dataset ini adalah untuk memahami faktor-faktor yang mempengaruhi seseorang untuk berbelanja di online store. Selain itu juga untuk meningkatkan tingkat konversi pembelian di online store, serta mengoptimalkan strategi marketing online store.

# %% [markdown]
# #**Assess Situation**

# %% [markdown]
# • Pertumbuhan e-commerce yang pesat.
#
# • Kebutuhan untuk memahami perilaku konsumen online.

# %% [markdown]
# #**Data Mining Goals**

# %% [markdown]
# • Mengidentifikasi faktor-faktor yang mempengaruhi seseorang untuk berbelanja di online store.
#
# • Membangun model prediktif untuk memprediksi kemungkinan pembelian di online store.
#
# • Memberikan rekomendasi untuk optimasi strategi marketing online store.

# %% [markdown]
# #**Project Plan**

# %% [markdown]
# Rencana proyek dimulai dengan mengumpulkan data dari berbagai sumber, seperti website online store, database pelanggan, survei online, dan lain-lain. Kemudian data dibersihkan, ditangani missing values nya, dan dilakukan transformasi data. Setelah itu data dianalisis untuk memahami pola dan tren. Lalu dibangun model prediktif menggunakan algoritma data mining yang sesuai. Terakhir, data dievaluasi kinerja model nya dan dipastikan lagi bahwa model sudah baik.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# #**Collect Initial Data**

# %% [markdown]
# Dataset **"Online Store Customer data"** ini merupakan sebuah dataset yang berisi data-data dari pelanggan dari toko online. Dataset ini bersumber dari kaggle.
#
# Berikut adalah link nya:
# https://www.kaggle.com/datasets/mountboy/online-store-customer-data

# %%
df_file = pd.read_csv('/content/online_store_customer_data.csv')

# %%
df_file
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0          2051.36
# 1           544.04
# 2          1572.60
# 3          1199.79
# 4              NaN
# ...            ...
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15
#
# [2512 rows x 11 columns]

# %% [markdown]
# #**Describe Data**

# %% [markdown]
# #Informasi Dasar

# %%
df_file.shape
# Out:
# (2512, 11)

# %% [markdown]
# Dataset **"Online Store Customer Data"** ini merupakan sebuah dataset yang memiliki kolom sebanyak **11 kolom**, dan memiliki baris sebanyak **2512 baris**.

# %% [markdown]
# #Informasi Lanjutan

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2357 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %% [markdown]
# Jadi kolom yang terdapat dalam dataset **"Online Store Customer Data"** ini adalah sebanyak 11 kolom dan memiliki 2512 baris.
#
#
# 1. Transaction Date (Tipe data: object): Kolom ini berisi tanggal dan waktu terjadinya transaksi.
# 2. Transaction Id (Tipe data: int64): Kolom ini berisi identifikasi unik untuk setiap transaksi. Biasanya berupa angka atau kombinasi angka dan huruf.
# 3. Gender (Tipe data: object): Kolom ini berisi informasi tentang jenis kelamin pelanggan.
# 4. Age (Tipe data: float64): Kolom ini berisi informasi tentang usia pelanggan.
# 5. Marital Status (Tipe data: object): Kolom ini berisi informasi tentang status pernikahan pelanggan.
# 6. State Names (Tipe data: object): Kolom ini berisi informasi tentang negara bagian atau provinsi tempat tinggal pelanggan.
# 7. Segment (Tipe data: object): Kolom ini berisi informasi tentang segmen atau kategori pelanggan.
# 8. Employees Status	(Tipe data: object): Kolom ini berisi informasi tentang status karyawan pelanggan.
# 9. Payment Method	(Tipe datta: object): Kolom ini berisi informasi tentang metode pembayaran yang digunakan pelanggan.
# 10. Referal	(Tipe data: float64): Kolom ini berisi informasi tentang sumber referral atau perujuk pelanggan, misalnya kode promo, iklan tertentu, atau nama referal lainnya.
# 11. Amount Spent (Tipe data: float64): Kolom ini berisi informasi tentang jumlah yang dibelanjakan pelanggan dalam transaksi tersebut.

# %% [markdown]
# #Informasi Statistik Deskriptif

# %%
df_file.describe()
# Out:
#        Transaction_ID          Age      Referal  Amount_spent
# count     2512.000000  2470.000000  2357.000000   2270.000000
# mean    152443.931131    46.637652     0.652100   1418.422577
# std        724.580482    18.186277     0.476405    878.507451
# min     151200.000000    15.000000     0.000000      2.090000
# 25%     151815.750000    32.000000     0.000000    678.192500
# 50%     152443.500000    47.000000     1.000000   1341.435000
# 75%     153071.250000    62.000000     1.000000   2038.102500
# max     153699.000000    78.000000     1.000000   2999.980000

# %% [markdown]
# Kolom:
#
# 1. Transaction_ID: Kolom ini berisi ID transaksi, yang merupakan pengenal unik untuk setiap transaksi.
# 2. Age: Kolom ini berisi usia pelanggan yang melakukan transaksi.
# 3. Referal: Kolom ini berisi informasi tentang bagaimana pelanggan mengetahui tentang toko, seperti melalui iklan, media sosial, atau dari teman.
# 4. Amount_spent: Kolom ini berisi jumlah yang dihabiskan pelanggan dalam transaksi.
#
#
#
#
#
# Baris:
#
# 1. count: Baris ini menunjukkan jumlah total transaksi yang dianalisis.
# 2. mean: Baris ini menunjukkan rata-rata untuk setiap kolom. Dalam hal ini, rata-rata ID transaksi adalah 152443.931131, rata-rata usia pelanggan adalah 46.637652, rata-rata nilai referral adalah 0.652100, dan rata-rata jumlah yang dihabiskan adalah 1418.422577.
# 3. std: Baris ini menunjukkan standar deviasi untuk setiap kolom. Standar deviasi adalah ukuran seberapa tersebar data di sekitar rata-rata. Semakin tinggi standar deviasi, semakin banyak data yang bervariasi dari rata-rata.
# 4. min: Baris ini menunjukkan nilai minimum untuk setiap kolom. Nilai minimum adalah nilai terendah yang ditemukan dalam kolom.
# 5. 25%: Baris ini menunjukkan kuartil pertama untuk setiap kolom. Kuartil pertama adalah nilai yang membagi data menjadi dua bagian, dengan 25% data di bawah kuartil pertama dan 75% data di atasnya.
# 6. 50%: Baris ini menunjukkan median untuk setiap kolom. Median adalah nilai tengah dalam kumpulan data.
# 7. 75%: Baris ini menunjukkan kuartil ketiga untuk setiap kolom. Kuartil ketiga adalah nilai yang membagi data menjadi dua bagian, dengan 75% data di bawah kuartil ketiga dan 25% data di atasnya.
# 8. max: Baris ini menunjukkan nilai maksimum untuk setiap kolom. Nilai maksimum adalah nilai tertinggi yang ditemukan dalam kolom.

# %% [markdown]
# #Exploratory Data Analysis

# %%
plt.pie(df_file["Gender"].value_counts(), labels=["Male", "Female"], autopct="%1.1f%%")
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa proporsi wanita yang berbelanja online lebih tinggi dibandingkan pria. Hal ini dapat disimpulkan bahwa gender merupakan salah satu faktor yang mempengaruhi seseorang berbelanja di online store.

# %%
plt.hist(df_file["Age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa pelanggan online store terbanyak berada pada usia 25-45 tahun. Hal ini menunjukkan bahwa usia merupakan faktor penting dalam menentukan target pasar online store.

# %%
plt.bar(df_file["Segment"].unique(), df_file["Segment"].value_counts())
plt.title("Customer Segmentation")
plt.xlabel("Segment")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa sebagian besar pelanggan online store berada di segmen Silver. Hal ini dapat menjadi informasi penting bagi online store untuk menentukan strategi marketing dan promosi yang sesuai dengan segmen Silver.

# %%
plt.pie(df_file["Employees_status"].value_counts(), labels=["Employees", "self-employee", "workers", "Unemployment"], autopct="%1.1f%%")
plt.title("Customer Online Store")
plt.show()

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa karyawan, wirausaha, dan pekerja lebih banyak melakukan pembelian di online store dibandingkan yang bukan karyawan(tidak memiliki pekerjaan). Hal ini bisa jadi karena gaji dari karyawan, wirausaha, dan pekerja lebih pasti serta mereka memiliki waktu yang terbatas untuk berbelanja di toko fisik dibanding dengan yang bukan karyawan(tidak memiliki pekerjaan).

# %%
plt.hist(df_file["Amount_spent"])
plt.title("Amount Spent Distribution")
plt.xlabel("Amount Spent")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Visualisasi diatas menunjukkan bahwa distribusi pengeluaran pelanggan online store tidak merata. Hal ini menunjukkan bahwa terdapat kelompok pelanggan yang melakukan pembelian dalam jumlah besar (high-value customers).

# %% [markdown]
# #**Verify Data Quality**

# %% [markdown]
# #Missing Values

# %%
df_file.isnull().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                  42
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %% [markdown]
# Berdasarkan output dataframe diatas, terdapat missing values pada beberapa kolom dataframe, yakni:
#
# 1. Kolom Gender memiliki 28 missing values.
# 2. Kolom Age memiliki 42 missing values.
# 2. Kolom Employees Status memiliki 26 missing values.
# 3. Kolom Referal memiliki 155 missing values.
# 4. Kolom Transaction Date, Transaction Id, Marital Status, State Names, Segment, dan Payment Method memiliki 0 missing values.

# %% [markdown]
# #Outliers Values

# %%
results = []

cols = df_file.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_file[col].quantile(0.25)
  q3 = df_file[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_file[(df_file[col] < lower_bound) | (df_file[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_file))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df_file = pd.DataFrame(results)
results_df_file.set_index('Kolom', inplace=True)
results_df_file = results_df_file.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df_file)
# Out:
# Kolom           Persentase Outliers
# Transaction_ID                  0.0
# Age                             0.0
# Referal                         0.0
# Amount_spent                    0.0

# %% [markdown]
# Tidak ada outliers

# %% [markdown]
# #Duplicated Values

# %%
df_file[df_file.duplicated()]
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 64         1/25/2019          151259    Male  73.0        Married
# 65         1/26/2019          151260    Male  55.0        Married
# 66         1/26/2019          151261  Female  72.0        Married
# 67         1/26/2019          151262    Male  15.0        Married
# 68         1/27/2019          151263  Female  63.0         Single
# 109         2/6/2019          151297    Male  60.0        Married
# 110         2/7/2019          151298  Female  45.0        Married
# 111         2/8/2019          151299    Male  33.0         Single
# 112         2/8/2019          151300    Male  24.0        Married
# 113         2/8/2019          151301  Female  53.0         Single
# 114         2/8/2019          151302  Female  70.0        Married
# 115         2/8/2019          151303    Male  16.0        Married
#
#         State_names   Segment Employees_status Payment_method  Referal  \
# 64    West Virginia     Basic        Employees         PayPal      0.0
# 65           Kansas     Basic        Employees          Other      1.0
# 66             Iowa    Silver     Unemployment         PayPal      NaN
# 67   South Carolina     Basic    self-employed          Other      1.0
# 68            Texas      Gold        Employees           Card      1.0
# 109            Utah    Silver     Unemployment          Other      1.0
# 110        Missouri  Platinum          workers          Other      1.0
# 111         Arizona    Silver          workers         PayPal      0.0
# 112  South Carolina     Basic     Unemployment          Other      0.0
# 113        Colorado     Basic    self-employed          Other      1.0
# 114   New Hampshire   Missing        Employees           Card      1.0
# 115        Nebraska     Basic          workers         PayPal      1.0
#
#      Amount_spent
# 64        1397.09
# 65        1277.64
# 66         515.77
# 67         790.10
# 68        1218.56
# 109        433.20
# 110        929.89
# 111       2560.26
# 112           NaN
# 113       1888.69
# 114        685.49
# 115       1264.73

# %% [markdown]
# Kolom:
# ---------
# Index:
# Kolom ini menunjukkan indeks baris pada dataframe.
#
# False:
# Kolom ini berisi nilai boolean yang menunjukkan apakah nilai pada baris tersebut merupakan duplikasi atau tidak. Nilai False menunjukkan bahwa nilai pada baris tersebut tidak duplikat, sedangkan nilai True menunjukkan bahwa nilai pada baris tersebut duplikat.
#
#
# Baris:
# ---------
# Setiap baris dalam dataframe mewakili satu baris data dalam dataframe asli. Nilai False pada setiap baris menunjukkan bahwa nilai pada baris tersebut tidak ditemukan di baris lain dalam dataframe.
#
# Kesimpulan:
# ------------
# Berdasarkan output dataframe, terdapat beberapa nilai duplikasi dalam dataframe, yakni:
#
# 1. Baris 64 dan 109 memiliki nilai yang sama di semua kolom.
# 2. Baris 66 dan 114 memiliki nilai yang sama di semua kolom kecuali kolom Gender.
# 3. Baris 67 dan 112 memiliki nilai yang sama di semua kolom kecuali kolom Marital_status.
# 4. Baris 113 dan 115 memiliki nilai yang sama di semua kolom kecuali kolom Age.

# %% [markdown]
# #**DATA PREPARATION**

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ###**Penanganan Missing Values**

# %% [markdown]
# #####**Pengecekkan Missing Values**

# %%
print((df_file.isna().sum() / len(df_file)) * 100)
# Out:
# Transaction_date    0.000000
# Transaction_ID      0.000000
# Gender              1.114650
# Age                 1.671975
# Marital_status      0.000000
# State_names         0.000000
# Segment             0.000000
# Employees_status    1.035032
# Payment_method      0.000000
# Referal             6.170382
# Amount_spent        9.633758
# dtype: float64

# %% [markdown]
# Dari output diatas, dapat diketahui bahwa kolom yang memiliki missing values adalah kolom gender, age, employees_status, referal, dan amount_spent.

# %% [markdown]
# **Nilai Kosong Pada Kolom Gender**

# %%
df_file[df_file['Gender'].isnull()]
# Out:
#      Transaction_date  Transaction_ID Gender   Age Marital_status  \
# 3            1/1/2019          151203    NaN  18.0         Single
# 72          1/29/2019          151267    NaN  37.0         Single
# 76          1/30/2019          151271    NaN  48.0        Married
# 176          3/5/2019          151364    NaN  40.0        Married
# 191         3/10/2019          151379    NaN  32.0         Single
# 207         3/16/2019          151395    NaN  67.0         Single
# 212         3/17/2019          151400    NaN  15.0         Single
# 231         3/23/2019          151419    NaN  62.0        Married
# 246         3/29/2019          151434    NaN  47.0        Married
# 261          4/2/2019          151449    NaN  62.0        Married
# 312         4/17/2019          151500    NaN  37.0         Single
# 333         4/22/2019          151521    NaN  40.0        Married
# 381          5/9/2019          151569    NaN  67.0        Married
# 420         5/19/2019          151608    NaN  67.0        Married
# 462          6/1/2019          151650    NaN  33.0        Married
# 492         6/10/2019          151680    NaN  16.0         Single
# 579          7/7/2019          151767    NaN  16.0        Married
# 624         7/23/2019          151812    NaN  53.0        Married
# 660          8/3/2019          151848    NaN  15.0        Married
# 849         10/6/2019          152037    NaN  57.0        Married
# 1508        5/22/2020          152696    NaN  48.0        Married
# 1571        6/11/2020          152759    NaN  52.0         Single
# 1646         7/9/2020          152834    NaN  46.0        Married
# 1881        9/23/2020          153069    NaN  40.0        Married
# 2028       11/12/2020          153216    NaN  37.0         Single
# 2157       12/31/2020          153345    NaN  72.0        Married
# 2436         4/7/2021          153624    NaN  18.0         Single
# 2510         5/1/2021          153698    NaN  44.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 3           Virginia  Platinum          workers           Card      1.0
# 72              Ohio     Basic     Unemployment          Other      1.0
# 76      North Dakota     Basic     Unemployment           Card      1.0
# 176         Colorado   Missing    self-employed         PayPal      1.0
# 191         Arkansas     Basic          workers          Other      1.0
# 207         Illinois      Gold        Employees           Card      1.0
# 212            Maine     Basic          workers           Card      1.0
# 231   North Carolina    Silver        Employees         PayPal      1.0
# 246     South Dakota  Platinum          workers          Other      1.0
# 261       New Mexico      Gold    self-employed         PayPal      0.0
# 312         Missouri    Silver        Employees         PayPal      0.0
# 333          Florida      Gold        Employees           Card      0.0
# 381         Maryland  Platinum        Employees         PayPal      1.0
# 420       New Mexico    Silver        Employees           Card      NaN
# 462       New Mexico   Missing          workers          Other      0.0
# 492      Mississippi     Basic          workers           Card      0.0
# 579       California     Basic          workers          Other      1.0
# 624        Wisconsin    Silver          workers         PayPal      1.0
# 660        Tennessee  Platinum    self-employed         PayPal      1.0
# 849           Oregon     Basic          workers         PayPal      1.0
# 1508  North Carolina    Silver    self-employed          Other      NaN
# 1571          Oregon     Basic        Employees         PayPal      0.0
# 1646        Virginia     Basic          workers           Card      0.0
# 1881         Alabama     Basic          workers         PayPal      0.0
# 2028       Minnesota  Platinum        Employees           Card      1.0
# 2157            Ohio     Basic    self-employed           Card      1.0
# 2436     Mississippi     Basic              NaN         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
#
#       Amount_spent
# 3          1199.79
# 72           52.08
# 76          828.41
# 176        1089.97
# 191         215.16
# 207        2562.33
# 212        1038.55
# 231        2909.85
# 246            NaN
# 261        1200.69
# 312         638.49
# 333        2092.27
# 381        2016.30
# 420        1305.22
# 462        1887.78
# 492         241.48
# 579        2848.56
# 624         467.43
# 660        1921.83
# 849         882.42
# 1508       1001.32
# 1571        105.04
# 1646       2621.11
# 1881       1716.37
# 2028       1368.19
# 2157        842.61
# 2436           NaN
# 2510       1909.77

# %% [markdown]
# **Nilai Kosong Pada Kolom Age**

# %%
df_file[df_file['Age'].isnull()]
# Out:
#      Transaction_date  Transaction_ID  Gender  Age Marital_status  \
# 268          4/4/2019          151456  Female  NaN        Married
# 279          4/7/2019          151467  Female  NaN        Married
# 295         4/11/2019          151483  Female  NaN         Single
# 340         4/25/2019          151528    Male  NaN         Single
# 450         5/28/2019          151638  Female  NaN         Single
# 518         6/19/2019          151706  Female  NaN        Married
# 540         6/24/2019          151728  Female  NaN        Married
# 583         7/10/2019          151771    Male  NaN         Single
# 657          8/2/2019          151845  Female  NaN         Single
# 732         8/26/2019          151920  Female  NaN        Married
# 750          9/1/2019          151938    Male  NaN        Married
# 755          9/2/2019          151943  Female  NaN         Single
# 806         9/23/2019          151994  Female  NaN        Married
# 826         9/30/2019          152014  Female  NaN        Married
# 857         10/9/2019          152045  Female  NaN         Single
# 1057       12/12/2019          152245  Female  NaN         Single
# 1294        2/26/2020          152482    Male  NaN        Married
# 1308         3/4/2020          152496  Female  NaN        Married
# 1403        4/11/2020          152591  Female  NaN        Married
# 1438        4/23/2020          152626  Female  NaN         Single
# 1513        5/23/2020          152701  Female  NaN        Married
# 1515        5/24/2020          152703    Male  NaN        Married
# 1518        5/25/2020          152706  Female  NaN         Single
# 1593        6/22/2020          152781    Male  NaN        Married
# 1673        7/18/2020          152861  Female  NaN         Single
# 1833         9/6/2020          153021    Male  NaN         Single
# 1893        9/27/2020          153081  Female  NaN        Married
# 1919        10/5/2020          153107    Male  NaN        Married
# 1924        10/6/2020          153112  Female  NaN        Married
# 2000        11/1/2020          153188  Female  NaN        Married
# 2001        11/2/2020          153189  Female  NaN        Married
# 2003        11/4/2020          153191  Female  NaN        Married
# 2045       11/21/2020          153233    Male  NaN        Married
# 2057       11/26/2020          153245    Male  NaN        Married
# 2108       12/11/2020          153296  Female  NaN        Married
# 2123       12/20/2020          153311    Male  NaN        Married
# 2130       12/21/2020          153318    Male  NaN         Single
# 2172         1/7/2021          153360  Female  NaN         Single
# 2336         3/7/2021          153524  Female  NaN        Married
# 2388        3/21/2021          153576  Female  NaN        Married
# 2413        3/30/2021          153601  Female  NaN         Single
# 2449        4/12/2021          153637  Female  NaN        Married
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 268       New Mexico     Basic     Unemployment           Card      1.0
# 279           Nevada     Basic    self-employed           Card      1.0
# 295          Indiana    Silver          workers         PayPal      0.0
# 340            Texas     Basic          workers           Card      0.0
# 450         Colorado   Missing          workers           Card      0.0
# 518         Illinois      Gold     Unemployment         PayPal      NaN
# 540          Indiana    Silver        Employees         PayPal      0.0
# 583         Kentucky     Basic        Employees           Card      1.0
# 657          Vermont  Platinum          workers         PayPal      1.0
# 732          Indiana     Basic        Employees           Card      1.0
# 750           Alaska     Basic          workers         PayPal      1.0
# 755     Pennsylvania     Basic        Employees          Other      0.0
# 806          Alabama     Basic          workers         PayPal      1.0
# 826      Mississippi      Gold        Employees          Other      1.0
# 857         Illinois    Silver        Employees          Other      1.0
# 1057         Arizona     Basic          workers         PayPal      1.0
# 1294          Nevada    Silver        Employees         PayPal      NaN
# 1308       Louisiana     Basic        Employees          Other      0.0
# 1403    Pennsylvania     Basic          workers         PayPal      1.0
# 1438         Florida     Basic        Employees         PayPal      1.0
# 1513      Washington    Silver        Employees           Card      1.0
# 1515        Kentucky     Basic          workers         PayPal      NaN
# 1518       Wisconsin  Platinum     Unemployment         PayPal      1.0
# 1593      Washington     Basic          workers         PayPal      0.0
# 1673         Arizona     Basic        Employees           Card      0.0
# 1833        Kentucky  Platinum    self-employed           Card      0.0
# 1893           Maine    Silver        Employees           Card      1.0
# 1919   West Virginia  Platinum          workers         PayPal      0.0
# 1924         Vermont    Silver          workers           Card      0.0
# 2000          Oregon     Basic    self-employed           Card      0.0
# 2001         Alabama      Gold        Employees          Other      0.0
# 2003            Iowa      Gold        Employees           Card      0.0
# 2045        Virginia     Basic        Employees         PayPal      0.0
# 2057  South Carolina   Missing          workers          Other      1.0
# 2108      California  Platinum    self-employed           Card      1.0
# 2123       Tennessee   Missing          workers         PayPal      1.0
# 2130       Tennessee    Silver          workers         PayPal      0.0
# 2172       Minnesota      Gold        Employees         PayPal      0.0
# 2336            Utah     Basic          workers          Other      0.0
# 2388      Washington     Basic    self-employed         PayPal      0.0
# 2413            Iowa    Silver          workers         PayPal      0.0
# 2449        Missouri    Silver    self-employed           Card      0.0
#
#       Amount_spent
# 268        2863.62
# 279        2414.29
# 295        1925.00
# 340         930.13
# 450         903.79
# 518        1083.38
# 540        1940.06
# 583          61.35
# 657         436.52
# 732        1239.91
# 750         664.37
# 755        1431.32
# 806            NaN
# 826        1250.55
# 857        1494.24
# 1057        282.07
# 1294        269.06
# 1308        720.49
# 1403        962.34
# 1438        644.43
# 1513           NaN
# 1515       1030.11
# 1518       1504.44
# 1593       1472.59
# 1673        400.75
# 1833        629.90
# 1893       1169.16
# 1919        651.96
# 1924       1214.75
# 2000       2094.06
# 2001       1954.13
# 2003        732.77
# 2045       1088.41
# 2057        104.03
# 2108       1267.04
# 2123           NaN
# 2130       2416.80
# 2172        921.00
# 2336       1518.77
# 2388       1467.30
# 2413        619.99
# 2449       1251.45

# %% [markdown]
# **Nilai Kosong Pada Kolom Employees_status**

# %%
df_file[df_file['Employees_status'].isnull()]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 179          3/6/2019          151367  Female  36.0         Single
# 253         3/31/2019          151441  Female  44.0         Single
# 301         4/13/2019          151489    Male  39.0         Single
# 447         5/28/2019          151635    Male  60.0        Married
# 577          7/7/2019          151765    Male  34.0        Married
# 582          7/9/2019          151770  Female  37.0        Married
# 682         8/10/2019          151870  Female  26.0         Single
# 688         8/12/2019          151876  Female  69.0        Married
# 788         9/16/2019          151976    Male  71.0         Single
# 796         9/20/2019          151984  Female  54.0        Married
# 919        10/26/2019          152107  Female  42.0        Married
# 1065       12/15/2019          152253  Female  47.0        Married
# 1195        1/24/2020          152383    Male  16.0         Single
# 1279        2/22/2020          152467  Female  50.0         Single
# 1290        2/25/2020          152478  Female  30.0         Single
# 1309         3/5/2020          152497    Male  61.0        Married
# 1395         4/7/2020          152583  Female  75.0        Married
# 1624         7/2/2020          152812  Female  21.0        Married
# 1660        7/14/2020          152848  Female  65.0        Married
# 1954       10/18/2020          153142  Female  43.0         Single
# 1961       10/20/2020          153149  Female  27.0        Married
# 2199        1/16/2021          153387  Female  25.0        Married
# 2201        1/17/2021          153389  Female  34.0         Single
# 2416         4/1/2021          153604  Female  46.0        Married
# 2436         4/7/2021          153624     NaN  18.0         Single
# 2459        4/14/2021          153647  Female  24.0         Single
#
#        State_names   Segment Employees_status Payment_method  Referal  \
# 179           Iowa     Basic              NaN         PayPal      1.0
# 253       Virginia  Platinum              NaN         PayPal      NaN
# 301    Mississippi    Silver              NaN           Card      0.0
# 447       Delaware     Basic              NaN           Card      0.0
# 577   South Dakota     Basic              NaN         PayPal      1.0
# 582       Missouri    Silver              NaN           Card      0.0
# 682        Florida     Basic              NaN         PayPal      1.0
# 688   Pennsylvania     Basic              NaN         PayPal      1.0
# 788         Oregon  Platinum              NaN         PayPal      1.0
# 796           Utah      Gold              NaN           Card      1.0
# 919           Iowa      Gold              NaN          Other      0.0
# 1065     Louisiana     Basic              NaN           Card      0.0
# 1195     Louisiana  Platinum              NaN          Other      0.0
# 1279      Colorado     Basic              NaN         PayPal      1.0
# 1290         Idaho     Basic              NaN         PayPal      0.0
# 1309        Kansas     Basic              NaN           Card      1.0
# 1395      Kentucky     Basic              NaN         PayPal      0.0
# 1624   Connecticut      Gold              NaN         PayPal      1.0
# 1660      Arkansas   Missing              NaN         PayPal      0.0
# 1954      Maryland      Gold              NaN         PayPal      0.0
# 1961  Rhode Island     Basic              NaN           Card      0.0
# 2199        Oregon     Basic              NaN         PayPal      0.0
# 2201        Oregon     Basic              NaN           Card      1.0
# 2416   Connecticut    Silver              NaN           Card      0.0
# 2436   Mississippi     Basic              NaN         PayPal      1.0
# 2459       Vermont     Basic              NaN           Card      1.0
#
#       Amount_spent
# 179         677.36
# 253        1226.06
# 301         329.20
# 447         176.49
# 577         786.73
# 582        1624.95
# 682         938.74
# 688         101.23
# 788        1188.81
# 796         243.97
# 919        1425.99
# 1065       2757.41
# 1195       1207.62
# 1279       1640.63
# 1290       2706.19
# 1309        126.08
# 1395       2854.02
# 1624        477.07
# 1660       1928.10
# 1954       2414.37
# 1961       1444.21
# 2199       1049.48
# 2201       1499.17
# 2416       1091.24
# 2436           NaN
# 2459        830.59

# %% [markdown]
# **Nilai Kosong Pada Kolom Referal**

# %%
df_file[df_file['Referal'].isnull()]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 58          1/25/2019          151258  Female  32.0         Single
# 61          1/26/2019          151261  Female  72.0        Married
# 66          1/26/2019          151261  Female  72.0        Married
# 74          1/29/2019          151269    Male  21.0        Married
# 77          1/30/2019          151272  Female  69.0         Single
# ...               ...             ...     ...   ...            ...
# 2358        3/13/2021          153546  Female  61.0        Married
# 2399        3/25/2021          153587  Female  31.0        Married
# 2417         4/1/2021          153605  Female  47.0        Married
# 2472        4/19/2021          153660  Female  16.0         Single
# 2489        4/26/2021          153677  Female  77.0        Married
#
#          State_names  Segment Employees_status Payment_method  Referal  \
# 58    South Carolina    Basic        Employees          Other      NaN
# 61              Iowa   Silver     Unemployment         PayPal      NaN
# 66              Iowa   Silver     Unemployment         PayPal      NaN
# 74           Montana    Basic        Employees         PayPal      NaN
# 77             Texas  Missing          workers           Card      NaN
# ...              ...      ...              ...            ...      ...
# 2358    Rhode Island    Basic        Employees           Card      NaN
# 2399    Rhode Island    Basic        Employees           Card      NaN
# 2417       Minnesota    Basic          workers          Other      NaN
# 2472      New Jersey    Basic    self-employed         PayPal      NaN
# 2489           Idaho    Basic          workers         PayPal      NaN
#
#       Amount_spent
# 58          676.70
# 61          515.77
# 66          515.77
# 74          340.38
# 77          489.47
# ...            ...
# 2358       1295.63
# 2399       2890.79
# 2417        941.84
# 2472       2027.31
# 2489       1524.83
#
# [155 rows x 11 columns]

# %% [markdown]
# **Nilai Kosong Pada Kolom Amount_spent**

# %%
df_file[df_file['Amount_spent'].isnull()]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 4            1/1/2019          151204    Male  27.0         Single
# 20           1/8/2019          151220  Female  19.0        Married
# 29          1/12/2019          151229  Female  62.0        Married
# 30          1/12/2019          151230    Male  17.0        Married
# 49          1/22/2019          151249  Female  73.0        Married
# ...               ...             ...     ...   ...            ...
# 2482        4/23/2021          153670  Female  77.0        Married
# 2484        4/24/2021          153672    Male  65.0         Single
# 2495        4/27/2021          153683  Female  20.0        Married
# 2496        4/28/2021          153684  Female  33.0        Married
# 2501        4/29/2021          153689  Female  65.0         Single
#
#       State_names   Segment Employees_status Payment_method  Referal  \
# 4     Connecticut     Basic    self-employed           Card      0.0
# 20         Hawaii   Missing          workers         PayPal      0.0
# 29        Indiana    Silver        Employees          Other      1.0
# 30          Maine     Basic        Employees         PayPal      1.0
# 49           Iowa     Basic     Unemployment           Card      0.0
# ...           ...       ...              ...            ...      ...
# 2482       Alaska    Silver          workers         PayPal      1.0
# 2484      Georgia     Basic        Employees           Card      1.0
# 2495   Washington  Platinum        Employees          Other      0.0
# 2496      Wyoming     Basic          workers           Card      0.0
# 2501       Nevada    Silver     Unemployment           Card      1.0
#
#       Amount_spent
# 4              NaN
# 20             NaN
# 29             NaN
# 30             NaN
# 49             NaN
# ...            ...
# 2482           NaN
# 2484           NaN
# 2495           NaN
# 2496           NaN
# 2501           NaN
#
# [242 rows x 11 columns]

# %% [markdown]
# #####**Hapus Missing Values**

# %% [markdown]
# Karena persentase nilai kosong pada kolom ***Gender***, ***Age***, ***Employees_status***, ***Referal***, dan ***Amount_spent*** tidak ada yang melebihi 70%, maka tidak ada kolom yang harus dihapus.

# %% [markdown]
# #####**Imputasi Missing Values**

# %% [markdown]
# ####Kolom Gender####
#
# Kolom Gender memiliki missing values < 70%. Karena kolom Gender kategorikal, maka gunakan modus untuk imputasi.

# %%
df_file['Gender'] = df_file['Gender'].fillna(df_file['Gender'].mode()[0])

# %% [markdown]
# ####Kolom Age####

# %%
df_file['Age'].dropna().describe()
# Out:
# count    2470.000000
# mean       46.637652
# std        18.186277
# min        15.000000
# 25%        32.000000
# 50%        47.000000
# 75%        62.000000
# max        78.000000
# Name: Age, dtype: float64

# %% [markdown]
# Disini berdasarkan hasil analisis statistik, kita dapat menggunakan mean dari kolom ***Age*** untuk imputasi nilai kosong tersebut

# %%
df_file['Age'] = df_file['Age'].fillna(df_file['Age'].dropna().mean())

# %% [markdown]
# ####Kolom Employees_status####
# Kolom Employees_status memiliki missing values < 70%. Karena kolom Employees_status kategorikal, maka gunakan modus untuk imputasi

# %%
df_file['Employees_status'] = df_file['Employees_status'].fillna(df_file['Employees_status'].mode()[0])

# %% [markdown]
# ####Kolom Referal####

# %%
df_file['Referal'].dropna().describe()
# Out:
# count    2357.000000
# mean        0.652100
# std         0.476405
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Referal, dtype: float64

# %% [markdown]
# Disini berdasarkan hasil analisis statistik, kita dapat menggunakan mean dari kolom ***Referal*** untuk imputasi nilai kosong tersebut

# %%
df_file['Referal'] = df_file['Referal'].fillna(df_file['Referal'].dropna().mean())

# %% [markdown]
# ####Kolom Amount_spent####

# %%
df_file['Amount_spent'].dropna().describe()
# Out:
# count    2270.000000
# mean     1418.422577
# std       878.507451
# min         2.090000
# 25%       678.192500
# 50%      1341.435000
# 75%      2038.102500
# max      2999.980000
# Name: Amount_spent, dtype: float64

# %% [markdown]
# Disini berdasarkan hasil analisis statistik, kita dapat menggunakan mean dari kolom ***Amount_spent*** untuk imputasi nilai kosong tersebut

# %%
df_file['Amount_spent'] = df_file['Amount_spent'].fillna(df_file['Amount_spent'].dropna().mean())

# %% [markdown]
# #####**Pengecekkan Ulang**

# %%
pd.DataFrame(df_file.isna().sum() / len(df_file) * 100, columns=['Null Ratio %'])
# Out:
#                   Null Ratio %
# Transaction_date           0.0
# Transaction_ID             0.0
# Gender                     0.0
# Age                        0.0
# Marital_status             0.0
# State_names                0.0
# Segment                    0.0
# Employees_status           0.0
# Payment_method             0.0
# Referal                    0.0
# Amount_spent               0.0

# %% [markdown]
# ###**Penanganan Duplicated Values**

# %% [markdown]
# #####**Pengecekkan Nilai Duplikat**

# %%
df_file[df_file.duplicated()]
# Out:
#     Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 64         1/25/2019          151259    Male  73.0        Married
# 65         1/26/2019          151260    Male  55.0        Married
# 66         1/26/2019          151261  Female  72.0        Married
# 67         1/26/2019          151262    Male  15.0        Married
# 68         1/27/2019          151263  Female  63.0         Single
# 109         2/6/2019          151297    Male  60.0        Married
# 110         2/7/2019          151298  Female  45.0        Married
# 111         2/8/2019          151299    Male  33.0         Single
# 112         2/8/2019          151300    Male  24.0        Married
# 113         2/8/2019          151301  Female  53.0         Single
# 114         2/8/2019          151302  Female  70.0        Married
# 115         2/8/2019          151303    Male  16.0        Married
#
#         State_names   Segment Employees_status Payment_method  Referal  \
# 64    West Virginia     Basic        Employees         PayPal   0.0000
# 65           Kansas     Basic        Employees          Other   1.0000
# 66             Iowa    Silver     Unemployment         PayPal   0.6521
# 67   South Carolina     Basic    self-employed          Other   1.0000
# 68            Texas      Gold        Employees           Card   1.0000
# 109            Utah    Silver     Unemployment          Other   1.0000
# 110        Missouri  Platinum          workers          Other   1.0000
# 111         Arizona    Silver          workers         PayPal   0.0000
# 112  South Carolina     Basic     Unemployment          Other   0.0000
# 113        Colorado     Basic    self-employed          Other   1.0000
# 114   New Hampshire   Missing        Employees           Card   1.0000
# 115        Nebraska     Basic          workers         PayPal   1.0000
#
#      Amount_spent
# 64    1397.090000
# 65    1277.640000
# 66     515.770000
# 67     790.100000
# 68    1218.560000
# 109    433.200000
# 110    929.890000
# 111   2560.260000
# 112   1418.422577
# 113   1888.690000
# 114    685.490000
# 115   1264.730000

# %% [markdown]
# Output diatas menampilkan kolom/baris apa saja yang memiliki nilai duplikat.

# %% [markdown]
# #####**Hapus Nilai Duplikat**

# %%
df_file = df_file.drop_duplicates()

# %%
df_file
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203  Female  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698  Female  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 0      2051.360000
# 1       544.040000
# 2      1572.600000
# 3      1199.790000
# 4      1418.422577
# ...            ...
# 2507    150.100000
# 2508    708.880000
# 2509   2030.070000
# 2510   1909.770000
# 2511   1073.150000
#
# [2500 rows x 11 columns]

# %% [markdown]
# Pada output diatas, kolom/baris yang memiliki nilai yang terduplikat telah dihapus.

# %% [markdown]
# ###**Penanganan Outliers**

# %% [markdown]
# #####**Pengecekkan Outliers**

# %%
results = []

cols = df_file.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_file[col].quantile(0.25)
  q3 = df_file[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_file[(df_file[col] < lower_bound) | (df_file[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_file))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom           Persentase Outliers
# Transaction_ID                  0.0
# Age                             0.0
# Referal                         0.0
# Amount_spent                    0.0

# %% [markdown]
# Pada dataset ini, **tidak terdapat outliers**.

# %% [markdown]
# #####**Pengecekkan Ulang**

# %%
results = []

cols = df_file.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_file[col].quantile(0.25)
  q3 = df_file[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_file[(df_file[col] < lower_bound) | (df_file[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_file))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df_file)
# Out:
# Kolom           Persentase Outliers
# Transaction_ID                  0.0
# Age                             0.0
# Referal                         0.0
# Amount_spent                    0.0

# %%
boxplot = df_file.drop('Transaction_ID', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# #**Construct Data**

# %% [markdown]
# ###**Melakukan Rekayasa Fitur (Feature Engineering)**

# %%
def categorize_age(age):
    if age < 18:
        return 'Child'
    elif 18 <= age < 60:
        return 'Adult'
    else:
        return 'Elderly'

df_file['AgeCategory'] = df_file['Age'].apply(categorize_age)
# Out:
# <ipython-input-98-37a7d73650f1>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_file
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203  Female  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698  Female  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent AgeCategory
# 0      2051.360000       Adult
# 1       544.040000       Adult
# 2      1572.600000     Elderly
# 3      1199.790000       Adult
# 4      1418.422577       Adult
# ...            ...         ...
# 2507    150.100000       Adult
# 2508    708.880000       Adult
# 2509   2030.070000       Adult
# 2510   1909.770000       Adult
# 2511   1073.150000       Adult
#
# [2500 rows x 12 columns]

# %% [markdown]
# Code dan output di atas merupakan pembuatan fitur baru yakni AgeCategory yang merupakan kategori dari umur. Dimana ada kategori Child/Anak-anak: <18 tahun, Adult/Dewasa: 18<=<60 tahun, dan Elderly/Lansia: >60 tahun.

# %%
def categorize_amount_spent(amount_spent):
    if amount_spent < 1023:
        return 'Small'
    elif amount_spent < 1542:
        return 'Medium'
    else:
        return 'Large'

df_file['AmountSpentCategory'] = df_file['Amount_spent'].apply(categorize_amount_spent)
# Out:
# <ipython-input-100-00b7015d5836>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_file
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203  Female  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698  Female  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# 1           Illinois     Basic    self-employed           Card      0.0
# 2         New Mexico     Basic          workers         PayPal      1.0
# 3           Virginia  Platinum          workers           Card      1.0
# 4        Connecticut     Basic    self-employed           Card      0.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent AgeCategory AmountSpentCategory
# 0      2051.360000       Adult               Large
# 1       544.040000       Adult               Small
# 2      1572.600000     Elderly               Large
# 3      1199.790000       Adult              Medium
# 4      1418.422577       Adult              Medium
# ...            ...         ...                 ...
# 2507    150.100000       Adult               Small
# 2508    708.880000       Adult               Small
# 2509   2030.070000       Adult               Large
# 2510   1909.770000       Adult               Large
# 2511   1073.150000       Adult              Medium
#
# [2500 rows x 13 columns]

# %% [markdown]
# Code dan output di atas merupakan pembuatan fitur baru yakni AmountSpentCategory yang merupakan kategori dari jumlah pembelian. Dimana ada kategori Small/Kecil: <1023, Large/Besar: =>1542, dan Medium/Sedang: <1542.

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df_file.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203  Female  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent  \
# 0     Basic     Unemployment          Other      1.0   2051.360000
# 1     Basic    self-employed           Card      0.0    544.040000
# 2     Basic          workers         PayPal      1.0   1572.600000
# 3  Platinum          workers           Card      1.0   1199.790000
# 4     Basic    self-employed           Card      0.0   1418.422577
#
#   AgeCategory AmountSpentCategory
# 0       Adult               Large
# 1       Adult               Small
# 2     Elderly               Large
# 3       Adult              Medium
# 4       Adult              Medium

# %% [markdown]
# #**Data Reduct**

# %% [markdown]
# ###**Mengurangi Fitur - Fitur Yang Kurang Relevan**

# %%
df_file_corr = df_file.corr(numeric_only=True)
px.imshow(df_file_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="01f65cae-7434-4d5c-882d-8b5299e5f299" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01f65cae-7434-4d5c-882d-8b5299e5f299")) {                    Plotly.newPlot(                        "01f65cae-7434-4d5c-882d-8b5299e5f299",                        [{"coloraxis":"coloraxis","name":"0","x":["Transaction_ID","Age","Referal","Amount_spent"],"y":["Transaction_ID","Age","Referal","Amount_spent"],"z":[[1.0,-0.008289273278934027,-0.0016525364570806826,-0.008447901510321173],[-0.008289273278934027,1.0,0.012583986112052544,-0.020921399937983712],[-0.0016525364570806826,0.012583986112052544,1.0,-0.0045074170106021065],[-0.008447901510321173,-0.020921399937983712,-0.0045074170106021065,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"col ...

# %%
df_file = df_file.drop(['Transaction_ID','Transaction_date','State_names','Segment','Payment_method'], axis=1)

# %%
df_file
# Out:
#       Gender   Age Marital_status Employees_status  Referal  Amount_spent  \
# 0     Female  19.0         Single     Unemployment      1.0   2051.360000
# 1       Male  49.0         Single    self-employed      0.0    544.040000
# 2       Male  63.0        Married          workers      1.0   1572.600000
# 3     Female  18.0         Single          workers      1.0   1199.790000
# 4       Male  27.0         Single    self-employed      0.0   1418.422577
# ...      ...   ...            ...              ...      ...           ...
# 2507  Female  57.0         Single    self-employed      0.0    150.100000
# 2508  Female  36.0        Married    self-employed      1.0    708.880000
# 2509    Male  22.0         Single          workers      1.0   2030.070000
# 2510  Female  44.0         Single        Employees      0.0   1909.770000
# 2511    Male  48.0         Single          workers      1.0   1073.150000
#
#      AgeCategory AmountSpentCategory
# 0          Adult               Large
# 1          Adult               Small
# 2        Elderly               Large
# 3          Adult              Medium
# 4          Adult              Medium
# ...          ...                 ...
# 2507       Adult               Small
# 2508       Adult               Small
# 2509       Adult               Large
# 2510       Adult               Large
# 2511       Adult              Medium
#
# [2500 rows x 8 columns]

# %% [markdown]
# Pada tahap ini, telah di lakukan pengurangan fitur yang tidak relevan serta fitur yang memiliki banyak sekali uniq values, yakni 'Transaction_ID','Transaction_date', 'State_names','Segment', 'Payment_method'.

# %% [markdown]
# #**Data Transformation**

# %% [markdown]
# ###**Mapping**

# %%
df_file['Gender'] = df_file['Gender'].map({'Male':1,'Female':0})
df_file['Marital_status'] = df_file['Marital_status'].map({'Single':1,'Married':0})
df_file['Employees_status'] = df_file['Employees_status'].map({'Employees':1,'workers':2,'self-employed':3,'Unemployment':4})
df_file['AgeCategory'] = df_file['AgeCategory'].map({'Child':1,'Adult':2, 'Elderly':3}).astype(int)
df_file['AmountSpentCategory'] = df_file['AmountSpentCategory'].map({'Small':1,'Medium':2, 'Large':3}).astype(int)

# %%
df_file
# Out:
#       Gender   Age  Marital_status  Employees_status  Referal  Amount_spent  \
# 0          0  19.0               1                 4      1.0   2051.360000
# 1          1  49.0               1                 3      0.0    544.040000
# 2          1  63.0               0                 2      1.0   1572.600000
# 3          0  18.0               1                 2      1.0   1199.790000
# 4          1  27.0               1                 3      0.0   1418.422577
# ...      ...   ...             ...               ...      ...           ...
# 2507       0  57.0               1                 3      0.0    150.100000
# 2508       0  36.0               0                 3      1.0    708.880000
# 2509       1  22.0               1                 2      1.0   2030.070000
# 2510       0  44.0               1                 1      0.0   1909.770000
# 2511       1  48.0               1                 2      1.0   1073.150000
#
#       AgeCategory  AmountSpentCategory
# 0               2                    3
# 1               2                    1
# 2               3                    3
# 3               2                    2
# 4               2                    2
# ...           ...                  ...
# 2507            2                    1
# 2508            2                    1
# 2509            2                    3
# 2510            2                    3
# 2511            2                    2
#
# [2500 rows x 8 columns]

# %% [markdown]
# Pada tahap mapping ini, data pada fitur berupa object telah diubah menjadi numeric agar lebih mudah pada saat pemodelan nanti. Yang diubah yakni fitur gender, marital_status, employees_status, dan agecategory.

# %% [markdown]
# ###**Encoding**

# %%
df_file = pd.get_dummies(df_file)

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df_file.head()
# Out:
#    Gender   Age  Marital_status  Employees_status  Referal  Amount_spent  \
# 0       0  19.0               1                 4      1.0   2051.360000
# 1       1  49.0               1                 3      0.0    544.040000
# 2       1  63.0               0                 2      1.0   1572.600000
# 3       0  18.0               1                 2      1.0   1199.790000
# 4       1  27.0               1                 3      0.0   1418.422577
#
#    AgeCategory  AmountSpentCategory
# 0            2                    3
# 1            2                    1
# 2            3                    3
# 3            2                    2
# 4            2                    2

# %% [markdown]
# #####Menyimpan Data yang telah di cleaning#####

# %%
df_file.to_csv("online-store-customer-data-cleaned.csv")

# %% [markdown]
# #**Select Modeling Techniques**

# %% [markdown]
# Algoritma Asosiatif:
#
# Algoritma asosiatif digunakan untuk menemukan hubungan antara variabel dalam data, seperti asosiasi antara item dalam data transaksional.
# Contoh algoritma asosiatif termasuk Apriori dan FP-Growth untuk penambangan aturan asosiasi dalam data transaksional.
# Algoritma asosiatif membantu dalam mengidentifikasi pola atau korelasi yang mungkin tersembunyi dalam data, seperti kebiasaan pembelian pelanggan atau hubungan antara variabel dalam dataset.

# %% [markdown]
# #**Modelling Associate**

# %% [markdown]
# ###**Pre-Processing**

# %% [markdown]
# #####**Validasi Silang**

# %%
inertia_values = []

k_range = range(2, 13)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_file)
    inertia_values.append(kmeans.inertia_)

plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.xticks(k_range)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %% [markdown]
# Code tersebut mengimplementasikan metode "Elbow" untuk menentukan jumlah kluster optimal dalam algoritma K-Means. Plot inertia terhadap jumlah kluster digunakan untuk menemukan titik "elbow", yang menandakan jumlah kluster optimal yang harus dipilih.

# %% [markdown]
# ###**Build Model**

# %% [markdown]
# #####**K-Means**

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_file)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters=3, random_state=42)

# %% [markdown]
# Code tersebut menggunakan algoritma K-Means untuk mengelompokkan data dalam df_file menjadi 4 klaster. Model K-Means dilatih dengan menggunakan data tersebut.

# %% [markdown]
# #####**Hierarchical Clustering**

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')

# %% [markdown]
# Code tersebut menggunakan algoritma Hierarchical Agglomerative Clustering (HAC) untuk mengelompokkan data menjadi 4 klaster. Metode pengukuran jarak antar titik menggunakan metrik Euclidean dan metode penggabungan klaster menggunakan metode ward.

# %% [markdown]
# ###**Begins and Compare Clusters**

# %%
kmeans_clust = kmeans.predict(df_file)
hierarchy_clust = hc.fit_predict(df_file)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %% [markdown]
# Code tersebut melakukan prediksi klaster untuk setiap data dalam df_file menggunakan model K-Means (kmeans) dan model Hierarchical Agglomerative Clustering (hc) yang telah dilatih sebelumnya.

# %%
x_final = pd.DataFrame(df_file).reset_index(inplace=True)

kmeans_col = pd.DataFrame(kmeans_clust, columns=["kmeans_cluster"])
hierarchy_col = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster"])

combined_data_assoc = pd.concat([df_file, kmeans_col, hierarchy_col], axis=1)

# %% [markdown]
# Code tersebut menggabungkan hasil klaster dari model K-Means dan Hierarchical Agglomerative Clustering dengan data asli dari df_file ke dalam satu DataFrame. Variabel x_final tidak diperlukan karena digunakan untuk mengatur ulang indeks DataFrame yang sudah ada. Variabel combined_data_assoc berisi data asli df_file bersama dengan kolom-kolom yang menunjukkan klaster hasil prediksi dari K-Means dan Hierarchical Agglomerative Clustering.

# %%
combined_data_assoc
# Out:
#       index  Gender   Age  Marital_status  Employees_status  Referal  \
# 0         0       0  19.0               1                 4      1.0
# 1         1       1  49.0               1                 3      0.0
# 2         2       1  63.0               0                 2      1.0
# 3         3       0  18.0               1                 2      1.0
# 4         4       1  27.0               1                 3      0.0
# ...     ...     ...   ...             ...               ...      ...
# 2495   2507       0  57.0               1                 3      0.0
# 2496   2508       0  36.0               0                 3      1.0
# 2497   2509       1  22.0               1                 2      1.0
# 2498   2510       0  44.0               1                 1      0.0
# 2499   2511       1  48.0               1                 2      1.0
#
#       Amount_spent  AgeCategory  AmountSpentCategory  kmeans_cluster  \
# 0      2051.360000            2                    3               1
# 1       544.040000            2                    1               0
# 2      1572.600000            3                    3               1
# 3      1199.790000            2                    2               1
# 4      1418.422577            2                    2               1
# ...            ...          ...                  ...             ...
# 2495    150.100000            2                    1               0
# 2496    708.880000            2                    1               0
# 2497   2030.070000            2                    3               1
# 2498   1909.770000            2                    3               1
# 2499   1073.150000            2                    2               1
#
#       hierarchy_cluster
# 0                     1
# 1                     0
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 2495                  0
# 2496                  0
# 2497                  1
# 2498                  1
# 2499                  0
#
# [2500 rows x 11 columns]

# %% [markdown]
# Tabel diatas adalah hasilnya.

# %% [markdown]
# #**Visualisasi**

# %%
sns.scatterplot(data=combined_data_assoc, x='Age', y='Amount_spent', hue='hierarchy_cluster', palette='viridis')

# Tampilkan plot
plt.xlabel('Age')
plt.ylabel('Amount_spent')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Code tersebut menggunakan pustaka Seaborn untuk membuat scatter plot dari data yang telah digabungkan (combined_data_assoc). Plot ini menunjukkan hubungan antara usia (Age) dan jumlah yang dihabiskan (Amount_spent), dengan pewarnaan berdasarkan klaster hasil prediksi dari model Hierarchical Agglomerative Clustering (hierarchy_cluster). Label sumbu x dan sumbu y ditambahkan menggunakan plt.xlabel() dan plt.ylabel(), sedangkan legenda untuk klaster ditampilkan dengan plt.legend(). Akhirnya, plot ditampilkan dengan plt.show().
#
# Visualisasi data ini menunjukkan bahwa:
#
# 1. Pembeli berusia 20-an rata-rata menghabiskan Rp 500.000 per transaksi online.
# 2. Pengeluaran rata-rata pembeli terus meningkat hingga mencapai puncaknya pada usia 40-an, dengan rata-rata Rp 3.000.000 per transaksi.
# 3. Setelah itu, pengeluaran rata-rata pembeli mulai menurun. Pembeli berusia 50-an rata-rata menghabiskan Rp 2.500.000, dan pembeli berusia 60-an rata-rata menghabiskan Rp 2.000.000 per transaksi.
# 4. Penurunan ini terus berlanjut hingga usia 80-an, di mana pembeli rata-rata hanya menghabiskan Rp 1.000.000 per transaksi.
#
# Visualisasi ini menunjukkan bahwa terdapat hubungan antara usia pembeli dan rata-rata pengeluaran mereka di toko online. Pembeli di usia 40-an memiliki rata-rata pengeluaran tertinggi, diikuti oleh pembeli di usia 30-an dan 50-an. Pengeluaran rata-rata kemudian menurun seiring dengan bertambahnya usia pembeli.
